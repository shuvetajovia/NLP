# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvetajovia/NLP/blob/main/Practice_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TOKENIZATION

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentences = ['I love you',
             "I'm love myself"
             'My day 2 progress ']

# %%
token = Tokenizer(num_words=100 , oov_token= "<OOV>")
token.fit_on_texts(sentences)
wordindex = token.word_index
print(wordindex)
# Out:
# {'<OOV>': 1, 'love': 2, 'i': 3, 'you': 4, "i'm": 5, 'myselfmy': 6, 'day': 7, '2': 8, 'progress': 9}

# %% [markdown]
# Sequences

# %%
sequence = token.texts_to_sequences(sentences)
padded = pad_sequences(sequence)
postpadding = pad_sequences(sequence , padding="post")
print(sequence,"\n")
print(padded,"\n")
print(postpadding)
# Out:
# [[3, 2, 4], [5, 2, 6, 7, 8, 9]]
#
# [[0 0 0 3 2 4]
#  [5 2 6 7 8 9]]
#
# [[3 2 4 0 0 0]
#  [5 2 6 7 8 9]]
